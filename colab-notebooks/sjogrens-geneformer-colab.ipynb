# %% [markdown]
# # Download data from cellxgene census
#
# > Only need to run this section once for initial data downloading. Skip this section on all proceeding runs due to import incompatibility errors

# %%
# !pip install -U cellxgene-census
# Out:
# Collecting cellxgene-census
#   Downloading cellxgene_census-1.17.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tiledbsoma>=1.15.3 (from cellxgene-census)
#   Downloading tiledbsoma-2.3.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.0 kB)
# Collecting anndata (from cellxgene-census)
#   Downloading anndata-0.12.10-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cellxgene-census) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from cellxgene-census) (2.32.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from cellxgene-census) (4.15.0)
# Collecting s3fs>=2021.06.1 (from cellxgene-census)
#   Downloading s3fs-2026.2.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiobotocore<4.0.0,>=2.19.0 (from s3fs>=2021.06.1->cellxgene-census)
#   Downloading aiobotocore-3.2.0-py3-none-any.whl.metadata (26 kB)
# Collecting fsspec==2026.2.0 (from s3fs>=2021.06.1->cellxgene-census)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2021.06.1->cellxgene-census) (3.13.3)
# Requirement already satisfied: attrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from tiledbsoma>=1.15.3->cellxgene-census) (25.4.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from tiledbsoma>=1.15.3->cellxgene-census) (10.8.0)
# Requirement already satisfied: pandas<3.0.0 in /usr/local/lib/python3.12/dist-packages (from tiledbsoma>=1.15.3->cellxgene-census) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tiledbsoma>=1.15.3->cellxgene-census) (18.1.0)
# Collecting scanpy>=1.9.2 (from tiledbsoma>=1.15.3->cellxgene-census)
#   Downloading scanpy-1.12-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tiledbsoma>=1.15.3->cellxgene-census) (1.16.3)
# Collecting somacore==1.0.29 (from tiledbsoma>=1.15.3->cellxgene-census)
#   Downloading somacore-1.0.29-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyarrow-hotfix (from somacore==1.0.29->tiledbsoma>=1.15.3->cellxgene-census)
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from somacore==1.0.29->tiledbsoma>=1.15.3->cellxgene-census) (2.1.2)
# Collecting array-api-compat>=1.7.1 (from anndata->cellxgene-census)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata->cellxgene-census) (3.15.1)
# Collecting legacy-api-wrap (from anndata->cellxgene-census)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->cellxgene-census) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata->cellxgene-census) (26.0)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata->cellxgene-census)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->cellxgene-census) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->cellxgene-census) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->cellxgene-census) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->cellxgene-census) (2026.1.4)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census)
#   Downloading aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.42.56,>=1.42.53 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census)
#   Downloading botocore-1.42.55-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census) (6.7.1)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census) (2.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census) (1.22.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->tiledbsoma>=1.15.3->cellxgene-census) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->tiledbsoma>=1.15.3->cellxgene-census) (2025.3)
# Collecting fast-array-utils>=1.2.1 (from fast-array-utils[accel,sparse]>=1.2.1->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census)
#   Downloading fast_array_utils-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (1.5.3)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (3.10.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.60.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (1.6.1)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.13.2)
# Collecting session-info2 (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census)
#   Downloading session_info2-0.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (4.67.3)
# Requirement already satisfied: umap-learn>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.5.11)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata->cellxgene-census)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->cellxgene-census) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata->cellxgene-census)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata->cellxgene-census) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (3.3.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.19.0->s3fs>=2021.06.1->cellxgene-census) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scanpy>=1.9.2->tiledbsoma>=1.15.3->cellxgene-census) (3.6.0)
# Downloading cellxgene_census-1.17.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.8 MB/s eta 0:00:00
# Downloading s3fs-2026.2.0-py3-none-any.whl (31 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 15.0 MB/s eta 0:00:00
# Downloading tiledbsoma-2.3.0-cp312-cp312-manylinux_2_28_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 61.9 MB/s eta 0:00:00:00:0100:01
# Downloading somacore-1.0.29-py3-none-any.whl (38 kB)
# Downloading anndata-0.12.10-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 19.2 MB/s eta 0:00:00
# Downloading aiobotocore-3.2.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 11.7 MB/s eta 0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 7.6 MB/s eta 0:00:00
# Downloading scanpy-1.12-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.3 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 30.0 MB/s eta 0:00:00
# Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.42.55-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 87.1 MB/s eta 0:00:00:00:0100:01
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading fast_array_utils-1.3.1-py3-none-any.whl (36 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 104.7 MB/s eta 0:00:0000:0100:01
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Downloading session_info2-0.4-py3-none-any.whl (17 kB)
# Installing collected packages: session-info2, pyarrow-hotfix, numcodecs, legacy-api-wrap, jmespath, fsspec, fast-array-utils, donfig, array-api-compat, aioitertools, zarr, botocore, anndata, aiobotocore, somacore, s3fs, scanpy, tiledbsoma, cellxgene-census
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.2.0 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.2.0 which is incompatible.
# Successfully installed aiobotocore-3.2.0 aioitertools-0.13.0 anndata-0.12.10 array-api-compat-1.14.0 botocore-1.42.55 cellxgene-census-1.17.0 donfig-0.8.1.post1 fast-array-utils-1.3.1 fsspec-2026.2.0 jmespath-1.1.0 legacy-api-wrap-1.5 numcodecs-0.16.5 pyarrow-hotfix-0.7 s3fs-2026.2.0 scanpy-1.12 session-info2-0.4 somacore-1.0.29 tiledbsoma-2.3.0 zarr-3.1.5

# %%
import cellxgene_census

census = cellxgene_census.open_soma(census_version="latest")
census["census_info"]["summary"].read().concat().to_pandas()

# Get all dataset citations from census
datasets = census["census_info"]["datasets"].read().concat().to_pandas()

# %% [markdown]
# ## Fetch AnnData from Census

# %%
import os

# Create the directory if it doesn't exist
os.makedirs("/content/raw-data", exist_ok=True)

# %%
# Fetch an AnnData object
dataset_id = "df1edb87-e512-43ae-b5f4-cb179cfc2bb4" # https://datasets.cellxgene.cziscience.com/31380664-ba9c-49d1-9961-b2bf4f7131a2.h5ad
cellxgene_census.download_source_h5ad(dataset_id, to_path="/content/raw-data/cxg_sjogrens.h5ad", progress_bar=True)
census.close()
# Out:
# Downloading: 100%|██████████| 418M/418M [00:07<00:00, 60.6MB/s]

# %% [markdown]
# ## Fetch citation for dataset

# %%
# Get a citation string for the slice
datasets[datasets["dataset_id"] == dataset_id].iloc[0]
# Out:
# soma_joinid                                                              1140
# citation                    Publication: https://doi.org/10.21203/rs.3.rs-...
# collection_id                            21bbfaec-6958-46bc-b1cd-1535752f6304
# collection_name             Single cell and spatial transcriptomics in Sjö...
# collection_doi                                    10.21203/rs.3.rs-3601404/v2
# collection_doi_label                Pranzatelli et al. (2024) Research Square
# dataset_id                               df1edb87-e512-43ae-b5f4-cb179cfc2bb4
# dataset_version_id                       31380664-ba9c-49d1-9961-b2bf4f7131a2
# dataset_title               scRNA-seq for GZMK+CD8+ T cells Target A Speci...
# dataset_h5ad_path                   df1edb87-e512-43ae-b5f4-cb179cfc2bb4.h5ad
# dataset_total_cell_count                                                94227
# Name: 1140, dtype: object

# %% [markdown]
# # Prepare data for Geneformer

# %% [markdown]
# #### The input data for Geneformer is single-cell RNA-seq (scRNAseq) data composed of a raw count matrix stored in .loom or .h5ad format. If data is in another format (e.g., .csv, .mtx), it should be converted to .loom or .h5ad using Scanpy or Anndata tools.
#
# #### No normalization, transformation, or feature selection should be performed. Removal of cells per standard quality controls (e.g., removal of empty droplets, damaged cells, doublets, etc.) is recommended.

# %%
import scanpy as sc
adata = sc.read_h5ad("/content/raw-data/cxg_sjogrens.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 94227 × 31969
#     obs: 'n_genes', 'n_counts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rp', 'pct_counts_rp', 'total_counts_hb', 'pct_counts_hb', 'Sample', 'batch', 'leiden', 'leiden_before', 'Immune_All_High.pkl', 'Immune_All_AddPIP.pkl', 'Immune_All_Low.pkl', 'Immune_All_PIP.pkl', 'Cells_Intestinal_Tract.pkl', 'Cells_Lung_Airway.pkl', 'Developing_Mouse_Brain.pkl', 'Nuclei_Lung_Airway.pkl', 'Pan_Fetal_Human.pkl', 'Focus Score', 'SSA', 'ANA', 'Annotation', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'development_stage_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'medical_background', 'suspension_type', 'sex_ontology_term_id', 'donor_id', 'is_primary_data', 'tissue_type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'mt', 'rp', 'hb', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'Cells_Lung_Airway.pkl_colors', 'Developing_Mouse_Brain.pkl_colors', 'Immune_All_AddPIP.pkl_colors', 'Immune_All_High.pkl_colors', 'Immune_All_Low.pkl_colors', 'Immune_All_PIP.pkl_colors', 'Nuclei_Lung_Airway.pkl_colors', 'Sample_colors', 'batch_condition', 'citation', 'default_embedding', 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'rank_genes_groups', 'schema_reference', 'schema_version', 'tissue_ontology_term_id_colors', 'title', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
adata.obs
# Out:
#                        n_genes  n_counts  n_genes_by_counts  total_counts  \
# TCAATTCTCTTGGTCC-1-1      7669  238340.0               7669      238340.0
# CAGATTGTCACGAACT-1-1      7949  236529.0               7949      236529.0
# TGATCTTTCTTGGTCC-1-1      6614  221995.0               6614      221995.0
# CCGTTCAAGACATATG-1-1      7965  221002.0               7965      221002.0
# GGGTTATCATCGAGCC-1-1      7341  219529.0               7341      219529.0
# ...                        ...       ...                ...           ...
# TACTTGTGTCTACAAC-1-38      154     218.0                154         218.0
# ATGGTTGTCGGAGATG-1-38       74     129.0                 74         129.0
# TTCCGGTTCGCGGACT-1-38      164     188.0                164         188.0
# AACCTTTGTTCATCTT-1-38      100     124.0                100         124.0
# GATCGTATCGACGTCG-1-38      101     127.0                101         127.0
#
#                        total_counts_mt  pct_counts_mt  total_counts_rp  \
# TCAATTCTCTTGGTCC-1-1              73.0       0.030629          27903.0
# CAGATTGTCACGAACT-1-1              36.0       0.015220          38970.0
# TGATCTTTCTTGGTCC-1-1               0.0       0.000000          39420.0
# CCGTTCAAGACATATG-1-1            1875.0       0.848409          27994.0
# GGGTTATCATCGAGCC-1-1               0.0       0.000000          38020.0
# ...                                ...            ...              ...
# TACTTGTGTCTACAAC-1-38              2.0       0.917431             28.0
# ATGGTTGTCGGAGATG-1-38              2.0       1.550388              3.0
# TTCCGGTTCGCGGACT-1-38              2.0       1.063830             11.0
# AACCTTTGTTCATCTT-1-38              0.0       0.000000              3.0
# GATCGTATCGACGTCG-1-38              0.0       0.000000              3.0
#
#                        pct_counts_rp  total_counts_hb  pct_counts_hb  ...  \
# TCAATTCTCTTGGTCC-1-1       11.707225              0.0       0.000000  ...
# CAGATTGTCACGAACT-1-1       16.475780              0.0       0.000000  ...
# TGATCTTTCTTGGTCC-1-1       17.757156              0.0       0.000000  ...
# CCGTTCAAGACATATG-1-1       12.666854              1.0       0.000452  ...
# GGGTTATCATCGAGCC-1-1       17.318897              0.0       0.000000  ...
# ...                              ...              ...            ...  ...
# TACTTGTGTCTACAAC-1-38      12.844036              1.0       0.458716  ...
# ATGGTTGTCGGAGATG-1-38       2.325581              0.0       0.000000  ...
# TTCCGGTTCGCGGACT-1-38       5.851064              0.0       0.000000  ...
# AACCTTTGTTCATCTT-1-38       2.419355              0.0       0.000000  ...
# GATCGTATCGACGTCG-1-38       2.362205              0.0       0.000000  ...
#
#                       is_primary_data tissue_type  \
# TCAATTCTCTTGGTCC-1-1             True      tissue
# CAGATTGTCACGAACT-1-1             True      tissue
# TGATCTTTCTTGGTCC-1-1             True      tissue
# CCGTTCAAGACATATG-1-1             True      tissue
# GGGTTATCATCGAGCC-1-1             True      tissue
# ...                               ...         ...
# TACTTGTGTCTACAAC-1-38            True      tissue
# ATGGTTGTCGGAGATG-1-38            True      tissue
# TTCCGGTTCGCGGACT-1-38            True      tissue
# AACCTTTGTTCATCTT-1-38            True      tissue
# GATCGTATCGACGTCG-1-38            True      tissue
#
#                                                        cell_type      assay  \
# TCAATTCTCTTGGTCC-1-1               acinar cell of salivary gland  10x 3' v3
# CAGATTGTCACGAACT-1-1               acinar cell of salivary gland  10x 3' v3
# TGATCTTTCTTGGTCC-1-1               acinar cell of salivary gland  10x 3' v3
# CCGTTCAAGACATATG-1-1                          myoepithelial cell  10x 3' v3
# GGGTTATCATCGAGCC-1-1               acinar cell of salivary gland  10x 3' v3
# ...                                                          ...        ...
# TACTTGTGTCTACAAC-1-38              acinar cell of salivary gland  10x 3' v3
# ATGGTTGTCGGAGATG-1-38  CD8-positive, alpha-beta cytotoxic T cell  10x 3' v3
# TTCCGGTTCGCGGACT-1-38                                 fibroblast  10x 3' v3
# AACCTTTGTTCATCTT-1-38  CD8-positive, alpha-beta cytotoxic T cell  10x 3' v3
# GATCGTATCGACGTCG-1-38            CD4-positive, alpha-beta T cell  10x 3' v3
#
#                                 disease     sex        tissue  \
# TCAATTCTCTTGGTCC-1-1             normal  female  labial gland
# CAGATTGTCACGAACT-1-1             normal  female  labial gland
# TGATCTTTCTTGGTCC-1-1             normal  female  labial gland
# CCGTTCAAGACATATG-1-1             normal  female  labial gland
# GGGTTATCATCGAGCC-1-1             normal  female  labial gland
# ...                                 ...     ...           ...
# TACTTGTGTCTACAAC-1-38  Sjogren syndrome  female  labial gland
# ATGGTTGTCGGAGATG-1-38  Sjogren syndrome  female  labial gland
# TTCCGGTTCGCGGACT-1-38  Sjogren syndrome  female  labial gland
# AACCTTTGTTCATCTT-1-38  Sjogren syndrome  female  labial gland
# GATCGTATCGACGTCG-1-38  Sjogren syndrome  female  labial gland
#
#                       self_reported_ethnicity  development_stage  \
# TCAATTCTCTTGGTCC-1-1         African American  35-year-old stage
# CAGATTGTCACGAACT-1-1         African American  35-year-old stage
# TGATCTTTCTTGGTCC-1-1         African American  35-year-old stage
# CCGTTCAAGACATATG-1-1         African American  35-year-old stage
# GGGTTATCATCGAGCC-1-1         African American  35-year-old stage
# ...                                       ...                ...
# TACTTGTGTCTACAAC-1-38       European American  50-year-old stage
# ATGGTTGTCGGAGATG-1-38       European American  50-year-old stage
# TTCCGGTTCGCGGACT-1-38       European American  50-year-old stage
# AACCTTTGTTCATCTT-1-38       European American  50-year-old stage
# GATCGTATCGACGTCG-1-38       European American  50-year-old stage
#
#                       observation_joinid
# TCAATTCTCTTGGTCC-1-1          p*esn;7zns
# CAGATTGTCACGAACT-1-1          B~?5gyw$k8
# TGATCTTTCTTGGTCC-1-1          0kYbSzkgca
# CCGTTCAAGACATATG-1-1          6CN0&gx15+
# GGGTTATCATCGAGCC-1-1          <p*%{_>GJr
# ...                                  ...
# TACTTGTGTCTACAAC-1-38         X95IfDnuo>
# ATGGTTGTCGGAGATG-1-38         a{*oSt0NK#
# TTCCGGTTCGCGGACT-1-38         918pjw$xmw
# AACCTTTGTTCATCTT-1-38         S3S|}CpDJN
# GATCGTATCGACGTCG-1-38         CtXhVT9qy6
#
# [94227 rows x 47 columns]

# %%
adata.var
# Out:
#                     mt     rp     hb  highly_variable         means  \
# ENSG00000243485  False  False  False            False  5.936808e-06
# ENSG00000237613  False  False  False            False  1.000000e-12
# ENSG00000186092  False  False  False            False  1.000000e-12
# ENSG00000239945  False  False  False            False  4.593860e-05
# ENSG00000239906  False  False  False            False  1.000000e-12
# ...                ...    ...    ...              ...           ...
# ENSG00000277856  False  False  False             True  3.515507e-02
# ENSG00000275063  False  False  False             True  2.517536e-02
# ENSG00000271254  False  False  False             True  3.006966e-02
# ENSG00000277475  False  False  False            False  1.000000e-12
# ENSG00000268674  False  False  False            False  1.000000e-12
#
#                  dispersions  dispersions_norm  feature_is_filtered  \
# ENSG00000243485    -0.580874         -3.119813                False
# ENSG00000237613          NaN          0.000000                False
# ENSG00000186092          NaN          0.000000                False
# ENSG00000239945     0.493031         -1.894246                False
# ENSG00000239906          NaN          0.000000                False
# ...                      ...               ...                  ...
# ENSG00000277856     6.892033          5.408454                False
# ENSG00000275063     3.115924          1.099064                False
# ENSG00000271254     2.679734          0.601274                False
# ENSG00000277475          NaN          0.000000                False
# ENSG00000268674          NaN          0.000000                False
#
#                     feature_name feature_reference feature_biotype  \
# ENSG00000243485      MIR1302-2HG    NCBITaxon:9606            gene
# ENSG00000237613          FAM138A    NCBITaxon:9606            gene
# ENSG00000186092            OR4F5    NCBITaxon:9606            gene
# ENSG00000239945  ENSG00000239945    NCBITaxon:9606            gene
# ENSG00000239906  ENSG00000239906    NCBITaxon:9606            gene
# ...                          ...               ...             ...
# ENSG00000277856  ENSG00000277856    NCBITaxon:9606            gene
# ENSG00000275063  ENSG00000275063    NCBITaxon:9606            gene
# ENSG00000271254  ENSG00000271254    NCBITaxon:9606            gene
# ENSG00000277475  ENSG00000277475    NCBITaxon:9606            gene
# ENSG00000268674  ENSG00000268674    NCBITaxon:9606            gene
#
#                 feature_length    feature_type
# ENSG00000243485            517          lncRNA
# ENSG00000237613           1015          lncRNA
# ENSG00000186092           2618  protein_coding
# ENSG00000239945           1319          lncRNA
# ENSG00000239906            323          lncRNA
# ...                        ...             ...
# ENSG00000277856            294  protein_coding
# ENSG00000275063            351  protein_coding
# ENSG00000271254           2922  protein_coding
# ENSG00000277475            831  protein_coding
# ENSG00000268674            510  protein_coding
#
# [31969 rows x 13 columns]

# %% [markdown]
# #### The genes must be labeled as Ensembl IDs. If your dataset includes only gene symbols instead, you can use external tools like Ensembl Biomart or MyGeneInfo to convert them.

# %%
# Duplicate index to a new .var column -> "ensembl_id"
adata.var["ensembl_id"] = adata.var.index

# %% [markdown]
# #### The data may contain additional feature labels that one would like to retain in the tokenized dataset, for example to use as labels for embeddings or fine-tuning, or to confirm balancing of attributes across data splits.

# %%
# Sjogren syndrome
# normal (control)
set(adata.obs["disease"])
# Out:
# {'Sjogren syndrome', 'normal'}

# %%
# cell type annotations from original authors
set(adata.obs["cell_type"])
# Out:
# {'B cell',
#  'CD4-positive, alpha-beta T cell',
#  'CD8-positive, alpha-beta cytotoxic T cell',
#  'CD8-positive, alpha-beta regulatory T cell',
#  'IgA plasma cell',
#  'IgG plasma cell',
#  'acinar cell of salivary gland',
#  'alternatively activated macrophage',
#  'dendritic cell',
#  'duct epithelial cell',
#  'effector CD8-positive, alpha-beta T cell',
#  'endothelial cell',
#  'fibroblast',
#  'inflammatory macrophage',
#  'ionocyte',
#  'mature NK T cell',
#  'myoepithelial cell',
#  'pro-T cell',
#  'smooth muscle cell'}

# %%
# collapse macrophage and plasma cell subtypes into broader categories
rename_dict = {
    "alternatively activated macrophage": "Macrophage",
    "inflammatory macrophage": "Macrophage",
    "IgA plasma cell": "Plasma cell",
    "IgG plasma cell": "Plasma cell"
}

# create unified cell-type annotation
adata.obs["cell_type_union"] = [
    rename_dict.get(ct, ct) for ct in adata.obs["cell_type"]
]

# sanity check
set(adata.obs["cell_type_union"])
# Out:
# {'B cell',
#  'CD4-positive, alpha-beta T cell',
#  'CD8-positive, alpha-beta cytotoxic T cell',
#  'CD8-positive, alpha-beta regulatory T cell',
#  'Macrophage',
#  'Plasma cell',
#  'acinar cell of salivary gland',
#  'dendritic cell',
#  'duct epithelial cell',
#  'effector CD8-positive, alpha-beta T cell',
#  'endothelial cell',
#  'fibroblast',
#  'ionocyte',
#  'mature NK T cell',
#  'myoepithelial cell',
#  'pro-T cell',
#  'smooth muscle cell'}

# %%
# reformat developmental stage / age attribute
set(adata.obs["development_stage"])

# keep only first two characters (e.g., "Adult" -> "Ad")
adata.obs["development_stage"] = [
    ds[:2] for ds in adata.obs["development_stage"]
]

# sanity check
set(adata.obs["development_stage"])
# Out:
# {'35',
#  '38',
#  '39',
#  '40',
#  '43',
#  '45',
#  '47',
#  '48',
#  '50',
#  '51',
#  '53',
#  '54',
#  '55',
#  '56',
#  '58',
#  '59',
#  '61',
#  '65',
#  '75'}

# %% [markdown]
# #### Optionally, one may provide a binary "filter_pass" attribute that indicates whether to include (1) or exclude (0) the cell from tokenization.

# %%
# select cell types relevant to complement production, regulation, and signaling
included_cell_types = [
    # myeloid
    "Macrophage",
    "Dendritic cell",

    # adaptive immune
    "B cell",
    "Plasma cell",
    "CD4-positive, alpha-beta T cell",
    "CD8-positive, alpha-beta cytotoxic T cell",
    "mature NK T cell",

    # stromal / vascular
    "fibroblast",
    "endothelial cell",
    "smooth muscle cell"
]

# create filter_pass flag for Geneformer tokenization
adata.obs["filter_pass"] = [
    1 if ct in included_cell_types else 0
    for ct in adata.obs["cell_type_union"]
]

# sanity check
adata.obs["filter_pass"].value_counts()
# Out:
# filter_pass
# 0    57375
# 1    36852
# Name: count, dtype: int64

# %%
import os
os.makedirs("/content/input-data/", exist_ok=True)

# %%
# Save prepared AnnData object for Geneformer tokenization
adata.write_h5ad("/content/input-data/cxg_sjogrens_prepared.h5ad")

# %%
custom_attrs = {
  "cell_type_union": "cell-type", # Here, this attribute is renamed
  "disease": "disease",
  "donor_id": "individual", # Patient ID, later used for data splits
  "development_stage": "age",
  "sex": "sex"
}

# %% [markdown]
# # Download Geneformer (colab installation)

# %%
# !git lfs install
# !git clone https://huggingface.co/ctheodoris/Geneformer
# Out:
# Git LFS initialized.
# Cloning into 'Geneformer'...
# remote: Enumerating objects: 1244, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 1244 (delta 11), reused 0 (delta 0), pack-reused 1217 (from 1)
# Receiving objects: 100% (1244/1244), 4.79 MiB | 11.68 MiB/s, done.
# Resolving deltas: 100% (806/806), done.
# Filtering content: 100% (24/24), 3.32 GiB | 32.61 MiB/s, done.

# %%
cd /content/Geneformer
# Out:
# /content/Geneformer

# %%
# !pip install .
# Out:
# Processing /content/Geneformer
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: anndata in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.12.10)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.49.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (3.6.0)
# Requirement already satisfied: loompy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (3.0.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.0.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.7.0)
# Requirement already satisfied: optuna-integration in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (26.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.2.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.18.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (18.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2025.2)
# Requirement already satisfied: ray in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.54.0)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (1.12)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (75.2.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.14.6)
# Requirement already satisfied: tdigest in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (0.5.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.19.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (4.67.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from geneformer==0.1.0) (5.0.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (1.14.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (3.15.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (8.4.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata->geneformer==0.1.0) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->geneformer==0.1.0) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->geneformer==0.1.0) (2025.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->geneformer==0.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->geneformer==0.1.0) (1.3.5)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (0.70.16)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (1.4.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->geneformer==0.1.0) (6.0.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from loompy->geneformer==0.1.0) (0.60.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from loompy->geneformer==0.1.0) (8.3.1)
# Requirement already satisfied: numpy-groupies in /usr/local/lib/python3.12/dist-packages (from loompy->geneformer==0.1.0) (0.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geneformer==0.1.0) (3.3.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->geneformer==0.1.0) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->geneformer==0.1.0) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->geneformer==0.1.0) (2.0.47)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft->geneformer==0.1.0) (0.7.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (1.1.2)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray->geneformer==0.1.0) (5.29.6)
# Requirement already satisfied: fast-array-utils>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from fast-array-utils[accel,sparse]>=1.2.1->scanpy->geneformer==0.1.0) (1.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (1.5.3)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (0.6.0)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (0.4)
# Requirement already satisfied: umap-learn>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from scanpy->geneformer==0.1.0) (0.5.11)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geneformer==0.1.0) (3.6.0)
# Requirement already satisfied: accumulation-tree in /usr/local/lib/python3.12/dist-packages (from tdigest->geneformer==0.1.0) (0.6.4)
# Requirement already satisfied: pyudorandom in /usr/local/lib/python3.12/dist-packages (from tdigest->geneformer==0.1.0) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.78.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (3.10.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->geneformer==0.1.0) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->geneformer==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->geneformer==0.1.0) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->geneformer==0.1.0) (0.24.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->geneformer==0.1.0) (1.3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (1.5.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->loompy->geneformer==0.1.0) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->geneformer==0.1.0) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->geneformer==0.1.0) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geneformer==0.1.0) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->geneformer==0.1.0) (3.0.3)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->geneformer==0.1.0) (0.16.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray->geneformer==0.1.0) (0.30.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers->geneformer==0.1.0) (0.24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->geneformer==0.1.0) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets->geneformer==0.1.0) (0.16.0)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->transformers->geneformer==0.1.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->transformers->geneformer==0.1.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers->geneformer==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers->geneformer==0.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers->geneformer==0.1.0) (0.1.2)
# Building wheels for collected packages: geneformer
#   Building wheel for geneformer (setup.py) ... done
#   Created wheel for geneformer: filename=geneformer-0.1.0-py3-none-any.whl size=2980779 sha256=e7f5ca3a9a0375e24823908a7f32adb7fff7c67e847cca28e1d71748a9e1d0a0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a4yfrjxi/wheels/2d/46/09/b7648deddd8f78de5e5a2785bbf00a6b4d1246c6d434192a76
# Successfully built geneformer
# Installing collected packages: geneformer
#   Attempting uninstall: geneformer
#     Found existing installation: geneformer 0.1.0
#     Uninstalling geneformer-0.1.0:
#       Successfully uninstalled geneformer-0.1.0
# Successfully installed geneformer-0.1.0

# %%
# ensure datasets updated in Colab environment
# !pip install gcsfs==2025.3.0
# !pip install datasets==3.6.0
# Out:
# Requirement already satisfied: gcsfs==2025.3.0 in /usr/local/lib/python3.12/dist-packages (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (3.13.3)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (4.4.2)
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2025.3.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (1.2.4)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gcsfs==2025.3.0) (2.32.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.22.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs==2025.3.0) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.30.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs==2025.3.0) (2026.1.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (4.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (1.72.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2025.3.0) (1.27.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs==2025.3.0) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2025.3.0) (3.3.1)
# Requirement already satisfied: datasets==3.6.0 in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets==3.6.0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets==3.6.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets==3.6.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets==3.6.0) (0.1.2)

# %% [markdown]
# # Tokenize data using Geneformer

# %% [markdown]
# #### The single-cell transcriptomic input data is then tokenized into rank value encodings that represent a nonparametric view of the transcriptome that prioritizes genes that uniquely distinguish cell states.
#
# #### For detailed documentation of the various arguments, please see here: https://geneformer.readthedocs.io/en/latest/geneformer.tokenizer.html

# %%
from geneformer import TranscriptomeTokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-271/2758153233.py in <cell line: 0>()
# ----> 1 from geneformer import TranscriptomeTokenizer
#
# /content/Geneformer/geneformer/__init__.py in <module>
#      15 ENSEMBL_MAPPING_FILE_30M = Path(__file__).parent / "gene_dictionaries_30m/ensembl_mapping_dict_gc30M.pkl"
#      16
# ---> 17 from . import (
#      18     collator_for_classification,
#      19     emb_extractor,
#
# /content/Geneformer/geneformer/collator_for_classification.py in <module>
#      10 import numpy as np
#      11 import torch
# ---> 12 from transformers import (
#      13     BatchEncoding,
#      14     DataCollatorForTokenClassification,
#
# ImportError: cannot import name 'SpecialTokensMixin' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tk = TranscriptomeTokenizer(
    custom_attr_name_dict=custom_attrs,
    chunk_size=512, # adjust based on available memory
    nproc=4, # adjust based on available CPU cores
    model_version="V1"
 )
tk.tokenize_data(
    data_directory="/content/input-data/",
    output_directory="/content/processed-data/",
    output_prefix="cm_tokenized",
    file_format="h5ad",
)

# %% [markdown]
# # Fine-tuning: single-task

# %% [markdown]
# #### The model embedding space can be fine-tuned towards a downstream biological question, such as distinguishing healthy from disease, to enable in silico perturbation experiments predicting which perturbations would induce desired cell state shifts within the embedding space.
#
# #### For detailed documentation of the various fine-tuning strategies and related arguments, please see here: https://geneformer.readthedocs.io/en/latest/geneformer.classifier.html

# %%
import os
os.makedirs("/content/finetuned_models", exist_ok=True)

# %%
# Generate a unique date-based identifier for each experiment
import datetime

current_date = datetime.datetime.now()
datestamp = f"{str(current_date.year)[-2:]}{current_date.month:02d}{current_date.day:02d}{current_date.hour:02d}{current_date.minute:02d}{current_date.second:02d}"
datestamp_min = f"{str(current_date.year)[-2:]}{current_date.month:02d}{current_date.day:02d}"

output_prefix = "cm_dz_classifier"
output_dir = f"/content/finetuned_models/{datestamp}"
print(datestamp)

# %%
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# #### The classifier is initialized here to distinguish cell states annotated within the "disease" attribute. Data is filtered to only perform the fine-tuning with cells specified in the "cell_type" attribute.
#
# #### Please note that, as usual with deep learning models, we **highly** recommend tuning learning hyperparameters for all fine-tuning applications as this can significantly improve model performance. Example below uses previously optimized hyperparameters, but one can optimize hyperparameters with the argument n_hyperopt_trials=n in cc.validate() where n>0 and represents the number of trials for hyperparameter optimization. Importantly, the hyperparameters provided here do not represent uniformly applicable or recommended hyperparameters. They are used only as an example for quickly executing the example notebook here.

# %%
from geneformer import Classifier

training_args = {
    "num_train_epochs": 0.9,
    "learning_rate": 0.000804,
    "lr_scheduler_type": "polynomial",
    "warmup_steps": 1812,
    "weight_decay":0.258828,
    "per_device_train_batch_size": 12,
    "seed": 73,
}

cc = Classifier(classifier="cell",
                cell_state_dict={"state_key": "disease", "states": "all"},
                filter_data={"cell-type": [
                    "Macrophage",
                    "Dendritic cell",
                    "B cell",
                    "Plasma cell",
                    "CD4-positive, alpha-beta T cell",
                    "CD8-positive, alpha-beta cytotoxic T cell",
                    "mature NK T cell",
                    "fibroblast",
                    "endothelial cell",
                    "smooth muscle cell"
                ]},
                training_args=training_args,
                max_ncells=37000, # 36,852 cells -> Number of cells selected for training earlier in notebook - Used 2000 for debugging
                freeze_layers=4,
                num_crossval_splits=5,
                forward_batch_size=32,
                nproc=10,
                model_version="V1" # default is V2, here set to V1 model to fit into Colab 40G GPU resources
)

# %% [markdown]
# #### Split the dataset into training, validation, and test sets based on individual IDs or predefined patient groups to avoid data leakage. Balance classes across splits as possible.
#
# #### Below, predefined splits are provided, which balance potential confounding variables such as age and sex.
#
# #### (Alternatively, one can use the built-in function to split the dataset. The arguments attr_to_split and attr_to_balance are both required for this method. Set attr_to_split to the attribute on which to split data (e.g., set to “individual” to split the data by individual patients into each group). Set attr_to_balance to the list of attribute keys on which to balance data while splitting on attr_to_split (e.g., ["age","sex"]).)

# %%
# Example: Define train/validation/test splits by donor_id
train_ids = ["NIDCRDC3556","NIDCRDC3561","NIDCRDC3617","NIDCRDC3622","NIDCRDC3247",
             "NIDCRDC3604","NIDCRDC3598","NIDCRDC3632","NIDCRDC3559","NIDCRDC3606",
             "NIDCRDC3621","NIDCRDC3618","NIDCRDC3630","NIDCRDC3607","NIDCRDC3564",
             "NIDCRDC3437"]  # ~60% of donors

eval_ids = ["NIDCRDC3560","NIDCRDC3596","NIDCRDC3592"]  # ~20% of donors
test_ids = ["NIDCRDC3623","NIDCRDC3614","NIDCRDC3603","NIDCRDC3633","NIDCRDC3637","NIDCRDC3546"]  # ~20% of donors

train_test_id_split_dict = {
    "attr_key": "individual",
    "train": train_ids + eval_ids,  # Train + eval for training
    "test": test_ids
}

train_valid_id_split_dict = {
    "attr_key": "individual",
    "train": train_ids,
    "eval": eval_ids
}

cc.prepare_data(input_data_file="/content/processed-data/cm_tokenized.dataset",
                output_directory=output_dir,
                output_prefix=output_prefix,
                split_id_dict=train_test_id_split_dict)

# %% [markdown]
# #### Perform fine-tuning with the training dataset, validating performance with held-out patients in the eval dataset.

# %%
all_metrics = cc.validate(
    model_directory=os.path.abspath("/content/Geneformer/Geneformer-V1-10M/"), # set to V1 model to fit into Colab 40G GPU resources
    prepared_input_data_file=f"{output_dir}/{output_prefix}_labeled_train.dataset",
    id_class_dict_file=f"{output_dir}/{output_prefix}_id_class_dict.pkl",
          output_directory=os.path.abspath(output_dir),
            output_prefix=output_prefix,
            attr_to_split="individual",
    attr_to_balance=["disease","age","sex"],
    n_hyperopt_trials=0 	# Number of trials to run for hyperparameter optimization. Set it to 0 for direct training without hyperparameter optimization.
)

# %% [markdown]
# #### Evaluate the final model on held-out patients in the test dataset.

# %%
all_metrics_test = cc.evaluate_saved_model(
model_directory=f"{output_dir}/{datestamp_min}_geneformer_cellClassifier_{output_prefix}/ksplit1/",
	id_class_dict_file=f"{output_dir}/{output_prefix}_id_class_dict.pkl",
     	test_data_file=f"{output_dir}/{output_prefix}_labeled_test.dataset",
     	output_directory=output_dir,
      	output_prefix=output_prefix,
    )

# %% [markdown]
# #### Plot confusion matrix and prediction confidence for held-out patients in the test dataset.

# %%
cc.plot_conf_mat(
    conf_mat_dict={"Geneformer": all_metrics["conf_matrix"]},
    output_directory=output_dir,
    output_prefix=output_prefix,
)

# %%
cc.plot_roc(
    roc_metric_dict={"Geneformer": all_metrics["all_roc_metrics"]},
    model_style_dict={"Geneformer": {"color": "red", "linestyle": "-"}},
    title="Dosage-sensitive vs -insensitive factors",
    output_directory=output_dir,
    output_prefix=output_prefix,
)

# %%
all_metrics

# %% [markdown]
# # Embedding extraction and visualization

# %% [markdown]
# #### Extract embeddings to visualize the fine-tuned embedding space.
#
# #### When extracting embeddings from the pretrained model prior to task-specific fine-tuning, setting emb_layer=-1 will extract embeddings from the second-to-last layer,  capturing more generalizable features than the last layer which is more closely linked to the pretraining objective of masked learning. However, because the fine-tuning learning objective is designed to directly reflect the biological question at hand, for the fine-tuned model, we recommend setting emb_layer=0 to extract embeddings from the final layer, which directly reflects features optimized for classification.
#
# #### For detailed documentation of the various arguments for embedding extraction, please see here: https://geneformer.readthedocs.io/en/latest/geneformer.emb_extractor.html

# %%
# !mkdir /content/embs

# %%
from geneformer import EmbExtractor

embex = EmbExtractor(
    model_type="CellClassifier", # set to GeneClassifier or Pretrained for those model types
    num_classes=2, # number of classes of fine-tuned model
    filter_data={"cell-type":[
        "Macrophage",
        "Dendritic cell",
        "B cell",
        "Plasma cell",
        "CD4-positive, alpha-beta T cell",
        "CD8-positive, alpha-beta cytotoxic T cell",
        "mature NK T cell",
        "fibroblast",
        "endothelial cell",
        "smooth muscle cell"
    ]}, # optionally can extract embeddings from a subset of cells based on the chosen attributes
    max_ncells=37000,
    emb_layer=0, # extracts embeddings from last layer
    emb_label=["disease", "individual"],
    labels_to_plot=["disease", "individual"],
    forward_batch_size=128,
    nproc=8,
    model_version="V1" # default is V2, here set to V1 model to fit into Colab 40G GPU resources
)

# Normalize and check the local model path we'll pass to the extractor
model_path = os.path.abspath(f"{output_dir}/{datestamp_min}_geneformer_cellClassifier_{output_prefix}/ksplit1").rstrip('/')
print('Will use model_path:', model_path)

# Ensure cfgp is defined for downstream diagnostics even if model path missing
cfgp = os.path.join(model_path, 'config.json')

# Helpful diagnostics before calling extraction
if os.path.exists(model_path):
    print('Model dir exists; listing first 50 entries:')
    try:
        print(os.listdir(model_path)[:50])
    except Exception as e:
        print('Could not list MODEL_DIR contents:', e)
    # check for key model files
    for key in ["config.json", "pytorch_model.bin", "model.safetensors"]:
        print(key, 'exists:', os.path.exists(os.path.join(model_path, key)))
    # if config.json exists, show a short preview to help troubleshooting
    cfgp = os.path.join(model_path, 'config.json')
    if os.path.exists(cfgp):
        try:
            with open(cfgp, 'r') as _f:
                import json
                cfg_preview = json.load(_f)
            print('config.json preview keys:', list(cfg_preview.keys()))
        except Exception as e:
            print('Could not read config.json:', e)
else:
    print('Model path does not exist:', model_path)

# Force HF/transformers to operate offline to avoid hub validation of local paths
os.environ['HF_HUB_OFFLINE'] = '1'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
print('Set HF_HUB_OFFLINE and TRANSFORMERS_OFFLINE to 1')

# Run embedding extraction with robust error handling to capture and print diagnostics
try:
    embs = embex.extract_embs(
        model_path,
        "/content/processed-data/cm_tokenized.dataset",
        "/content/embs",
        "cm_finetuned_embs",
    )
    print('Embedding extraction completed; sample shape/info:')
    try:
        print(getattr(embs, 'shape', None))
    except Exception:
        pass
except Exception as exc:
    import traceback
    print('Embedding extraction failed with exception:')
    traceback.print_exc()
    print('\n--- Additional MODEL_DIR diagnostics follow ---')
    try:
        print('Model dir:', model_path)
        print('Contents:', os.listdir(model_path))
    except Exception as e:
        print('Could not list model_path contents:', e)
    # try to surface config.json contents if present
    try:
        if os.path.exists(cfgp):
            with open(cfgp, 'r') as _f:
                import json
                print('config.json:')
                print(json.dumps(json.load(_f), indent=2))
    except Exception as e:
        print('Failed to print config.json:', e)
    raise

# %%
# plot umap of cell embeddings
embex.plot_embs(embs=embs,
                plot_style="umap",
                output_directory="/content/embs",
                output_prefix="emb_umap",
                max_ncells_to_plot=10000)

# %%
# plot heatmap of cell embeddings
embex.plot_embs(embs=embs,
                plot_style="heatmap",
                output_directory="/content/embs",
                output_prefix="emb_heatmap",
                max_ncells_to_plot=10000)

# %% [markdown]
# # In silico perturbation to induce desired cell states

# %% [markdown]
# #### The fine-tuned model is leveraged for in silico perturbation analysis to predict gene perturbations that would induce desired cell state shifts within the embedding space, for example from disease to healthy.
#
# #### In silico perturbation experiments can also be performed to predict the impact of perturbations on other genes, indicating network connections.
#
# #### The in silico perturbation strategy is versatile in terms of the perturbation type (e.g., delete, overexpress), target gene(s) to perturb individually or in combination, cells to test, model to use, and perturbation goal embedding states (e.g., source state, target state, alternate state).
#
# #### For detailed documentation of the various in silico perturbation strategies and related arguments, please see here: https://geneformer.readthedocs.io/en/latest/geneformer.in_silico_perturber.html

# %%
# !mkdir /content/isp

# %% [markdown]
# #### Extract embedding positions of goal state for calculating shifts

# %%
from geneformer import EmbExtractor, InSilicoPerturber

# Extract embedding positions of goal state for calculating shifts.
# Using labels that exist in this tokenized dataset (Sjogren data) instead of the cardiomyopathy example.
cell_states_to_model = {
    "state_key": "disease",
    "start_state": "Sjogren syndrome",  # cells to perturb
    "goal_state": "normal",              # desired target state
    "alt_states": []                       # no alternate states for this example
}

embex = EmbExtractor(
    model_type="CellClassifier",
    num_classes=2, # number of classes of fine-tuned model
    # Use the same cell types we used for fine-tuning so filtering matches this dataset
    filter_data={"cell-type":[
        "Macrophage",
        "Dendritic cell",
        "B cell",
        "Plasma cell",
        "CD4-positive, alpha-beta T cell",
        "CD8-positive, alpha-beta cytotoxic T cell",
        "mature NK T cell",
        "fibroblast",
        "endothelial cell",
        "smooth muscle cell"
    ]},
     max_ncells=37000,
     emb_mode="cell",  # V1 models don't have a CLS token; use cell embeddings
     emb_layer=0, # extracts embeddings from last layer
     emb_label=None,  # must be None for get_state_embs
     labels_to_plot=None,
     forward_batch_size=128,
     nproc=8,
     model_version="V1", # default is V2
     summary_stat="exact_mean",  # required for extracting exact state embeddings
 )

state_embs_dict = embex.get_state_embs(cell_states_to_model,
                    model_directory=f"{output_dir}/{datestamp_min}_geneformer_cellClassifier_{output_prefix}/ksplit1/",
                    input_data_file="/content/processed-data/cm_tokenized.dataset",
                    output_directory="/content/isp",
                    output_prefix=output_prefix
                    )

# %% [markdown]
# #### Perform in silico perturbation, providing the goal embedding positions in cell_states_to_model.

# %%
perturbation_type = "delete" # or "overexpress"
# genes_to_perturb = "all"
genes_to_perturb = [
    "ENSG00000173376", # C1QA
    "ENSG00000159259", # C1QB
    "ENSG00000159261", # C1QC
    "ENSG00000159403", # C1R
    "ENSG00000182326", # C1S
    "ENSG00000166278", # C2
    "ENSG00000125733", # C3
    "ENSG00000244731", # C4A
    "ENSG00000242110", # C4B
    "ENSG00000106804", # C5
    "ENSG00000039068", # C6
    "ENSG00000112936", # C7
    "ENSG00000188513", # C8A
    "ENSG00000165917", # C8B
    "ENSG00000130635", # C8G
    "ENSG00000113600", # C9
    "ENSG00000243649", # CFB (Factor B)
    "ENSG00000197409", # CFD (Factor D)
    "ENSG00000126746", # CFP (Properdin)
    "ENSG00000165457", # MBL2
    "ENSG00000127241", # MASP1
    "ENSG00000114737", # MASP2
    "ENSG00000000971", # CFH (Factor H)
    "ENSG00000184489", # CFI (Factor I)
    "ENSG00000149131", # SERPING1 (C1-INH)
    "ENSG00000117350", # CD46 (MCP)
    "ENSG00000163504", # CD55 (DAF)
    "ENSG00000085063", # CD59
    "ENSG00000123838", # C4BPA
    "ENSG00000123843", # C4BPB
    "ENSG00000203710", # CR1
    "ENSG00000117322", # CR2
    "ENSG00000138382", # C3AR1
    "ENSG00000197405", # C5AR1
    "ENSG00000067646", # ITGAM (CR3 Alpha)
    "ENSG00000198081", # ITGAX (CR4 Alpha)
    "ENSG00000113119", # ITGB2 (CD18)
    "ENSG00000163914", # CFHR1
    "ENSG00000134765", # CFHR2
    "ENSG00000169896", # CFHR3
    "ENSG00000140678", # CFHR4
    "ENSG00000160255"  # CFHR5
]

isp = InSilicoPerturber(perturb_type=perturbation_type,
                        genes_to_perturb=genes_to_perturb,
                        model_type="CellClassifier",
                        num_classes=2,
                        emb_mode="cell",
                        filter_data={"cell-type":[
                            "Macrophage",
                            "Dendritic cell",
                            "B cell",
                            "Plasma cell",
                            "CD4-positive, alpha-beta T cell",
                            "CD8-positive, alpha-beta cytotoxic T cell",
                            "mature NK T cell",
                            "fibroblast",
                            "endothelial cell",
                            "smooth muscle cell"
                        ]},
                        cell_states_to_model=cell_states_to_model,
                        state_embs_dict=state_embs_dict,
                        max_ncells=37000,
                        emb_layer=0,
                        forward_batch_size=32,  # REDUCED
                        nproc=1,                # REDUCED
                        model_version="V1"
                        )

# %%
isp.perturb_data(model_directory = f"{output_dir}/{datestamp_min}_geneformer_cellClassifier_{output_prefix}/ksplit1/",
                 input_data_file="/content/processed-data/cm_tokenized.dataset",
                 output_directory="/content/isp",
                 output_prefix=output_prefix)

# %%
# !mkdir /content/results

# %% [markdown]
# #### Aggregate data from in silico perturbation experiments and perform statistics.
#
# #### In this case the analysis mode is "goal_state_shift" given the in silico perturbation was set up to predict perturbations that shift cells towards a goal cell state.
#
# #### For detailed documentation of the various in silico perturbation stat modes, related arguments, and description of output column meanings, please see here: https://geneformer.readthedocs.io/en/latest/geneformer.in_silico_perturber_stats.html

# %%
from geneformer import InSilicoPerturberStats

cell_states_to_model = {
    "state_key": "disease",
    "start_state": "Sjogren syndrome",  # cells to perturb
    "goal_state": "normal",              # desired target state
    "alt_states": []                       # no alternate states for this example
}

ispstats = InSilicoPerturberStats(mode="goal_state_shift",
    genes_perturbed=genes_to_perturb,
    combos=0,
    anchor_gene=None,
    cell_states_to_model=cell_states_to_model,
    model_version="V1"  # default is V2, here set to V1 model to fit into Colab 40G GPU resources
)


# Extracts data from intermediate files and processes stats to output in final .csv
ispstats.get_stats("/content/isp",
                   None,
                   "/content/results",
                   "isd_gsshift")

# %% [markdown]
# #### Load output csv as dataframe to review results

# %%
import pandas as pd
gss_results = pd.read_csv("/content/results/isd_gsshift.csv",index_col=0)
gss_results

# %% [markdown]
# #### Analysis mode "aggregate_data"
#
# #### This analysis mode gives the magnitude of the change without forcing the cells to shift to only normal or diseased states; enables more complex outcomes.

# %%
ispstats = InSilicoPerturberStats(mode="aggregate_data",
    genes_perturbed=genes_to_perturb,
    combos=0,
    anchor_gene=None,
    cell_states_to_model=cell_states_to_model,
    model_version="V1"  # default is V2, here set to V1 model to fit into Colab 40G GPU resources
)


# Extracts data from intermediate files and processes stats to output in final .csv
ispstats.get_stats("/content/isp",
                   None,
                   "/content/results",
                   "isd_aggd")

# %% [markdown]
# #### Load output csv as dataframe to review results

# %%
import pandas as pd
agg_results = pd.read_csv("/content/results/isd_aggd.csv",index_col=0)
agg_results

# %% [markdown]
# #### The above in silico perturbation was only performed on 100 cells for the purposes of demonstrating the code. Below, in silico perturbation results from a larger number of cells is downloaded for visualization of results.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='white')

# Filter for genes with significant shifts in both directions
df = full_results[(full_results['Goal_end_FDR'] < 0.05) & (full_results['Alt_end_FDR_hcm'] < 0.05)]

# Further filter for genes shifting towards one state and away from the other
df = df[((df['Shift_to_goal_end'] > 0) & (df['Shift_to_alt_end_hcm'] < 0)) |
        ((df['Shift_to_goal_end'] < 0) & (df['Shift_to_alt_end_hcm'] > 0))]

# Filter for number of cells with that gene expressed
df = df[df["N_Detections"] > 100]

n_top_genes = 15
top_genes = df.loc[df[["Shift_to_goal_end", "Shift_to_alt_end_hcm"]].abs().sum(axis=1).sort_values(ascending=False).index]["Gene_name"].tolist()[:n_top_genes]

# List of genes you want to annotate
genes_to_annotate = top_genes + ["C3", "CFH", "C3AR1"]

# Scatter plot of shift to goal state (NF) vs shift to alternate state (HCM)
plt.figure(figsize=(6, 6))
sns.scatterplot(data=df,
                x='Shift_to_goal_end',
                y='Shift_to_alt_end_hcm',
                color='red',  # Color for significant points with desired shifts
                size='N_Detections',  # Size based on the number of detections
                sizes=(20, 200),  # Adjust marker sizes
                legend='brief')

# Add titles and labels
plt.title('Candidate therapeutic targets whose in silico repression \n in DCM cardiomyocytes shifts towards NF, away from HCM', fontsize=16)
plt.xlabel('Shift to goal state (NF)', fontsize=14)
plt.ylabel('Shift to alternate state (HCM)', fontsize=14)

# Add a reference line where shifts to NF and HCM are equal
plt.axline((0, 0), slope=1, color='gray', linestyle='--')

# Add red dotted lines to mark zero positions on both axes
plt.axhline(0, color='red', linestyle=':', linewidth=1.5)
plt.axvline(0, color='red', linestyle=':', linewidth=1.5)

# # Annotate selected genes
for _, row in df.iterrows():
    if row['Gene_name'] in genes_to_annotate:
        plt.text(row['Shift_to_goal_end'], row['Shift_to_alt_end_hcm'], row['Gene_name'],
                 fontsize=10, color='black', weight='bold')

# Show plot
plt.tight_layout()
plt.show()
